# %% [markdown]
# <a href="https://colab.research.google.com/github/userctf/yandex-stud-camp-24/blob/yolo-baseline/ml/baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install supervision  ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.0/871.0 kB 33.7 MB/s eta 0:00:00
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow
import supervision as sv
from ultralytics import YOLO
model = YOLO("yolov8s.pt")
# Out:
# 0: 320x640 1 snowboard, 41.7ms
# Speed: 3.1ms preprocess, 41.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# 1

# %%
image = cv2.imread('Shotcut_00_00_46_750.jpg')
result = model(image,   conf=0.3)[0]
detections = sv.Detections.from_ultralytics(result)


for i, item in enumerate(detections.data['class_name']):
  print(f'{item}: {detections.confidence[i]}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2d9bd33f5c0f> in <cell line: 1>()
# ----> 1 image = cv2.imread('Shotcut_00_00_46_750.jpg')
#       2 result = model(image,   conf=0.3)[0]
#       3 detections = sv.Detections.from_ultralytics(result)
#       4
#       5
#
# NameError: name 'cv2' is not defined

# %%
box_annotator = sv.BoxAnnotator()
annotated_frame = box_annotator.annotate(
  scene=image.copy(),
  detections=detections)
cv2_imshow(annotated_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1709x793>
